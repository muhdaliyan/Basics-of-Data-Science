# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('mpg')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df1 = df.drop(['name'], axis=1)
df1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
df1.describe().transpose()
# Out:
#               count         mean         std     min       25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.500    23.0
# cylinders     398.0     5.454774    1.701004     3.0     4.000     4.0
# displacement  398.0   193.425879  104.269838    68.0   104.250   148.5
# horsepower    392.0   104.469388   38.491160    46.0    75.000    93.5
# weight        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5
# acceleration  398.0    15.568090    2.757689     8.0    13.825    15.5
# model_year    398.0    76.010050    3.697627    70.0    73.000    76.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   262.000   455.0
# horsepower     126.000   230.0
# weight        3608.000  5140.0
# acceleration    17.175    24.8
# model_year      79.000    82.0

# %%
df1.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin
# 32           71     usa
# 126          74     usa
# 330          80  europe
# 336          80     usa
# 354          81  europe
# 374          82     usa

# %%
df1.dropna(inplace = True)

# %%
df1.isnull().sum().any()
# Out:
# False

# %%
df1.shape
# Out:
# (392, 8)

# %% [markdown]
# ## Part 2
# **Univariante Analysis**

# %%
df1['model_year'] = df1['model_year'] + 1900
df1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0        1970    usa
# 1        1970    usa
# 2        1970    usa
# 3        1970    usa
# 4        1970    usa

# %%
df.cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
df.cylinders.value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10, 6))
sns.countplot(data = df1, x = 'cylinders',  palette='cubehelix')
plt.show()

# %%
df1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0        1970    usa
# 1        1970    usa
# 2        1970    usa
# 3        1970    usa
# 4        1970    usa

# %%
plt.figure(figsize = (10, 6))
sns.countplot(data = df1, x = df1['model_year'],  palette='cubehelix')
plt.show()

# %%
sns.displot(df1['horsepower'])
plt.show()

# %%
sns.displot(df1['displacement'])
plt.show()

# %% [markdown]
# ## Part 3
# **Bivariante Analysis**

# %%
df1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0        1970    usa
# 1        1970    usa
# 2        1970    usa
# 3        1970    usa
# 4        1970    usa

# %%
plt.figure(figsize = (8, 4))
sns.boxplot(x=df1['cylinders'], y=df1['mpg'], palette='Spectral')
plt.show()

# %%
plt.figure(figsize = (8, 4))
sns.boxplot(x=df1['model_year'], y=df1['mpg'], palette='Spectral')
plt.show()

# %% [markdown]
# ## Part 3
# **Multivariante Analysis**

# %%
df1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0        1970    usa
# 1        1970    usa
# 2        1970    usa
# 3        1970    usa
# 4        1970    usa

# %%
sns.lmplot(x='model_year', y='mpg', hue='origin', data=df1, palette='rainbow')
plt.show()

# %%
sns.lmplot(x='acceleration', y='mpg', hue='origin', data=df1, palette='rainbow')
plt.show()

# %%
sns.lmplot(x='displacement', y='mpg', hue='origin', data=df1, palette='rainbow')
plt.show()

# %%
sns.lmplot(x='weight', y='mpg', hue='origin', data=df1, palette='rainbow')
plt.show()

# %%
df1.to_csv('correlation_mpg.csv', index=False)
